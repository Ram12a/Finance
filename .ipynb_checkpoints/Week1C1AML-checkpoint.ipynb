# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
from IPython import display
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
with open('/home/gaston/MachineLearning/DatosMl/train.npy', 'rb') as fin:
    X = np.load(fin)
    
with open('/home/gaston/MachineLearning/DatosMl/target.npy', 'rb') as fin:
    y = np.load(fin)

# %%
print(X.shape)
print(y.shape)
# Out:
# (826, 2)
# (826,)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', s=50)

# %%
from ClassML import Features
from ClassML import OwnModels

# %%
Feat = Features()
Mod = OwnModels()

# %%
CreateFeatures = Feat.expandQuadratics(X)

# %%
dummy_weights = np.linspace(-1, 1, 6)
Mod.VisualizeGradientWeight(X, y, dummy_weights, [0.5, 0.5, 0.25],h=0.01)

# %%
w = np.array([0, 0, 0, 0, 0, 1])
Mod.MiniBathGD(CreateFeatures,y,w,100,4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-36ee36798c40> in <module>
#       1 w = np.array([0, 0, 0, 0, 0, 1])
# ----> 2 Mod.MiniBathGD(CreateFeatures,y,w,100,4)
#
# AttributeError: 'OwnModels' object has no attribute 'MiniBathGD'
