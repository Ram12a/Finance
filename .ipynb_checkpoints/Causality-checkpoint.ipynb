# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import sklearn
import tigramite
from tigramite import data_processing as pp
from tigramite import plotting as tp
from tigramite.pcmci import PCMCI
from tigramite.independence_tests import ParCorr, GPDC, CMIknn, CMIsymb
import pandas as pd
# Out:
# Could not import rpy package
# Could not import r-package RCIT

# %%
#np.random.seed(42)     # Fix random seed
#links_coeffs = {0: [((0, -1), 0.7), ((1, -1), -0.8)],
#                1: [((1, -1), 0.8), ((3, -1), 0.8)],
#                2: [((2, -1), 0.5), ((1, -2), 0.5), ((3, -3), 0.6)],
#                3: [((3, -1), 0.4)],
#                }
#T = 1000     # time series length
#data, true_parents_neighbors = pp.var_process(links_coeffs, T=T)
#T,N = data.shape

# Initialize dataframe object, specify time axis and variable names
#var_names = [r'$X^0$', r'$X^1$', r'$X^2$', r'$X^3$']
#dataframe = pp.DataFrame(data, 
#                         datatime = np.arange(len(data)), 
#                         var_names=var_names)

# %%
#dataframe

# %%
#parcorr = ParCorr(significance='analytic')
#pcmci = PCMCI(
#    dataframe=dataframe, 
#    cond_ind_test=parcorr,
#    verbosity=1)

# %%
#correlations = pcmci.get_lagged_dependencies(tau_max=20)
#lag_func_matrix = tp.plot_lagfuncs(val_matrix=correlations, setup_args={'var_names':var_names, 
#                                    'x_base':5, 'y_base':.5})

# %%
#pcmci.verbosity = 1
#results = pcmci.run_pcmci(tau_max=8, pc_alpha=None)

# %%
#q_matrix = pcmci.get_corrected_pvalues(p_matrix=results['p_matrix'], fdr_method='fdr_bh')
#pcmci.print_significant_links(
#        p_matrix = results['p_matrix'], 
#        q_matrix = q_matrix,
#        val_matrix = results['val_matrix'],
#       alpha_level = 0.01)

# %%
#link_matrix = pcmci.return_significant_parents(pq_matrix=q_matrix,
     #                   val_matrix=results['val_matrix'], alpha_level=0.01)['link_matrix']

# %%
#tp.plot_graph(
#    val_matrix=results['val_matrix'],
#    link_matrix=link_matrix,
#    var_names=var_names,
#    link_colorbar_label='cross-MCI',
#    node_colorbar_label='auto-MCI',
#    )

# %%
#tp.plot_time_series_graph(
#    val_matrix=results['val_matrix'],
#    link_matrix=link_matrix,
#    var_names=var_names,
#    link_colorbar_label='MCI',
#    )

# %%
import pickle as pkl

# %%
with open('/home/gaston/MachineLearning/LS1BASE.pkl', 'rb') as f:
    Base = pkl.load(f)

# %%
Base.columns
# Out:
# Index(['Func_Chancador_3', 'Func_Chancador_4', 'Corriente_Chancador_3',
#        'Corriente_Chancador_4', 'Experto_Sag_4', 'Presion_Descansos',
#        'Func_Correa_13', 'Func_Correa_14', 'Nivel_Bin_55', 'Nivel_Bin_54',
#        'Temperatura_Bushing_Chancador_4', 'Temperatura_Retorno_Chancador_4',
#        'Pebble_Procesado', 'Pebble_Generado', 'Tonelaje_SAG4', 'PebbleMenos34',
#        'PebbleMas12', 'P50', 'P80', 'Nivel1', 'Nivel2', 'LimiteMaxTonalaje',
#        'LimiteMinTonelaje', 'TonelajeSetPoint', 'Gruesos', 'Medios', 'Finos',
#        'Potencia', 'Corriente_Feeder_6', 'Corriente_Feeder_7',
#        'Corriente_Feeder_8', 'Corriente_Feeder_9', 'Corriente_Feeder_10',
#        'Corriente_Feeder_11', 'Corriente_Feeder_12', 'Corriente_Feeder_13',
#        'Velocidad_Feeder_6', 'Velocidad_Feeder_7', 'Velocidad_Feeder_8',
#        'Velocidad_Feeder_9', 'Velocidad_Feeder_10', 'Velocidad_Feeder_11',
#        'Velocidad_Feeder_12', 'Velocidad_Feeder_13', 'Ratio_Feeder_6',
#        'Ratio_Feeder_7', 'Ratio_Feeder_8', 'Ratio_Feeder_9', 'Ratio_Feeder_10',
#        'Ratio_Feeder_11', 'Ratio_Feeder_12', 'Ratio_Feeder_13',
#        'Peso_Correa_Alim', 'Peso_Correa_AlimSP', 'NivelSP1', 'NivelSP2',
#        'NivelSP3', 'NivelSP4', 'NivelSP5', 'NivelSP6',
#        'VelocidadSag4MaxExperto', 'VelocidadSag4MinExperto', 'VelocidadSag4',
#        'PorcentajeSolidoMin', 'PorcentajeSolidoMax', 'PorcentajeSolido',
#        'ImpactosAudio', 'AguaProcesada', 'GranuCV22_0_19', 'GranuCV22_0_44',
#        'GranuCV22_0_75', 'GranuCV22_1_25', 'GranuCV22_10_00', 'GranuCV22_2_00',
#        'GranuCV22_4_00', 'GranuCV22_6_00', 'GranuCV22_8_00', 'MaximoPresion',
#        'PresionDesc', 'PresionAlim1', 'PresionAlim2', 'PresionAlim3',
#        'PresionAlim4', 'PresionDesc1', 'PresionDesc2', 'PresionDesc3',
#        'PresionDesc4', 'PotenciaMB1', 'PotenciaMB2', 'PotenciaMB3',
#        'PotenciaMB4', 'CorrienteMB4', 'Tonelaje104', 'Tonelaje102',
#        'Tonelaje231', 'Tonelaje232', 'Tripper', 'EstadoSAG4', 'Turno'],
#       dtype='object')

# %%
plt.plot(Base['2017-10-05 08:30:00':'2017-10-05 09:00:00'][['Presion_Descansos']])

# %%
plt.plot(Base['2017-10-05 08:30:00':'2017-10-05 09:00:00'][['MaximoPresion']])

# %%
plt.plot(Base['2017-10-05 08:30:00':'2017-10-05 09:00:00'][['Potencia']])

# %%
plt.plot(Base['2017-09-23 15:20:00':'2017-09-23 15:50:00'][['LimiteMaxTonalaje']])

# %%
plt.plot(Base['2017-09-23 15:20:00':'2017-09-23 15:50:00'][['Tonelaje_SAG4']])

# %%
Base['Operativo'] = 0
Base['Operativo'].loc[Base['Tonelaje_SAG4']>=4000] = 1

# %%
Base[['Tonelaje_SAG4','Operativo']].head()
# Out:
#                      Tonelaje_SAG4  Operativo
# Timestamp
# 2017-07-01 00:00:00        5820.39          1
# 2017-07-01 00:01:00        5843.40          1
# 2017-07-01 00:02:00        5854.19          1
# 2017-07-01 00:03:00        5904.00          1
# 2017-07-01 00:04:00        5867.99          1

# %%
'''
Generar un rango rolling cada 1 minuto y de largo de 10 minutos
Calcular la correlacion 
'''
from datetime import datetime, timedelta

fecha1 = '2018-07-01 01:00:00'
a = list()
fecha = list()
for i in np.arange(10000):
    if fecha1 == '2018-07-01 01:00:00':
        fecha1 = pd.to_datetime(fecha1)
        fecha2 = fecha1 + timedelta(minutes=10)
        fecha1 = str(fecha1)
        fecha2 = str(fecha2)
        Bas = Base[['Presion_Descansos','Potencia','Operativo']][fecha1:fecha2]
        cor = Bas.corr().iloc[0,1]
        presionSub = Bas['Presion_Descansos'].iloc[-1]-Bas['Presion_Descansos'].iloc[0]
        Suma = Bas['Operativo'].sum()
        if ((cor<0.1) & (presionSub>100) & (Suma >= 11)):
            print(str(fecha1) + ' ' + str(cor))
        fecha1 = pd.to_datetime(fecha1)+timedelta(minutes=5)
    else:
        fecha1 = pd.to_datetime(fecha1)
        fecha2 = fecha1 + timedelta(minutes=10)
        fecha1 = str(fecha1)
        fecha2 = str(fecha2)
        Bas = Base[['Presion_Descansos','Potencia','Operativo']][fecha1:fecha2]
        cor = Bas.corr().iloc[0,1]
        presionSub = Bas['Presion_Descansos'][-1]-Bas['Presion_Descansos'][0]
        Suma = Bas['Operativo'].sum()
        if (cor<0.1) & (presionSub>100) & (Suma >= 11):
            print(str(fecha1) + ' ' + str(cor))
        fecha1 = pd.to_datetime(fecha1)+timedelta(minutes=5)
# Out:
# 2018-07-12 00:35:00 -0.6830365696101934
# 2018-07-12 15:40:00 -0.6279708404149991
# 2018-07-12 16:30:00 -0.6580656271011444
# 2018-07-12 22:25:00 -0.38773955247260883
# 2018-07-12 22:30:00 -0.8754977887450853
# 2018-07-13 09:10:00 -0.5679952854618058
# 2018-07-15 11:00:00 -0.8319918132513031
# 2018-07-16 13:55:00 -0.6869233288038467
# 2018-07-16 14:00:00 -0.7723628175187396
# 2018-07-16 16:10:00 -0.029676791460783968
# 2018-07-17 09:45:00 -0.5106840100717458
# 2018-07-20 12:10:00 -0.8397008368612102
# 2018-07-20 16:25:00 -0.9252278224275059
# 2018-07-20 16:30:00 -0.9174859861342815
# 2018-07-21 02:40:00 -0.9679414928452839
# 2018-07-21 06:15:00 -0.9527098031430217
# 2018-07-21 07:35:00 -0.9418288310251501
# 2018-07-21 21:30:00 -0.864117084425526
# 2018-07-22 12:20:00 -0.979394397752539
# 2018-07-22 20:45:00 -0.9531705437043523
# 2018-07-23 10:20:00 -0.9557927628125286
# 2018-07-23 13:15:00 -0.9485524822390109
# 2018-07-23 21:45:00 -0.9661215321615924
# 2018-07-24 03:30:00 -0.9878943500801922
# 2018-07-24 04:05:00 -0.8619251666762645
# 2018-07-25 06:40:00 -0.9656109862021066
# 2018-07-25 06:45:00 -0.9732156024944247
# 2018-07-25 07:40:00 -0.9671433574478616
# 2018-07-25 14:40:00 -0.9606022692025009
# 2018-07-25 15:35:00 -0.9385510629182259
# 2018-07-25 16:05:00 -0.9783741911741214
# 2018-07-25 16:10:00 -0.9895093406643063
# 2018-07-26 21:40:00 -0.28210404465793876
# 2018-07-26 21:45:00 0.07715693775764307
# 2018-07-26 21:50:00 -0.9787253355457677
# 2018-07-26 21:55:00 -0.9738874060239091
# 2018-07-26 22:00:00 -0.7996371427750486
# 2018-07-28 06:20:00 -0.6598958305274142
# 2018-07-28 21:15:00 -0.38034595677966726
# 2018-07-28 23:35:00 -0.34584471650548926
# 2018-07-28 23:45:00 -0.09054379538526416
# 2018-07-29 10:30:00 -0.7328071364566451
# 2018-07-30 03:10:00 -0.8166110910570223
# 2018-07-30 18:00:00 -0.9185548733140395
# 2018-07-30 18:05:00 -0.8176634349814097
# 2018-08-01 18:20:00 -0.9508052300973329
# 2018-08-02 09:25:00 -0.9469359964068147
# 2018-08-02 09:30:00 -0.6834646484048162
# 2018-08-02 13:40:00 -0.9757461266080284
# 2018-08-03 22:40:00 -0.9900633728259909

# %%
fechaDetectada = '2018-08-01 18:20:00'
fecha1a = str(pd.to_datetime(fechaDetectada) - timedelta(minutes=30))
fecha1b = str(pd.to_datetime(fechaDetectada) + timedelta(minutes=30))
Tags = ['Presion_Descansos','MaximoPresion','Potencia',
        'LimiteMaxTonalaje','Medios','Gruesos',
        'Pebble_Procesado','Pebble_Generado','Tonelaje_SAG4']

# %%
for i in Tags:
    plt.plot(Base[fecha1a:fecha1b][i])
    plt.title(i)
    plt.axvline(x=fechaDetectada,color='red')
    plt.figure()

# %%
plt.hist(b)

# %%
plt.plot(Base1['Presion_Descansos'])

# %%
#Base1['Presion_Descansos'].describe()
# Out:
# count    6.000000e+01
# mean     1.000000e+00
# std      1.131537e-08
# min      9.999999e-01
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      1.000000e+00
# Name: Presion_Descansos, dtype: float64

# %%
var_names = ['PresionDesc','Potencia','Medios','Gruesos']
Base1Hora = Base['2018-06-13 10:00:00':'2018-06-13 23:00:00'][var_names]
Base1Hora = Base1Hora.diff(5)
#Base1Horadiff.columns = ['PresionDescDiff','PotenciaDiff','MediosDiff','GruesosDiff']
#Base1Horadiff5 = Base1Hora.diff(5)
#Base1Horadiff5.columns = ['PresionDescDiff5','PotenciaDiff5','MediosDiff5','GruesosDiff5']
#Base1Horadiff10 = Base1Hora.diff(10)
#Base1Horadiff10.columns = ['PresionDescDiff10','PotenciaDiff10','MediosDiff10','GruesosDiff10']
#Base1Hora = pd.concat([Base1Hora,Base1Horadiff],axis=1)
Base1Hora = (Base1Hora-Base1Hora.mean())/Base1Hora.std()
Base1Hora = Base1Hora.dropna()
#for i in Base1Hora.columns:
#    print(i)
#    Base1Hora = Base1Hora[Base1Hora[i]!=0]
var_names = ['PresionDesc','Potencia','Medios','Gruesos']

# %%
dataframe = pp.DataFrame(np.array(Base1Hora), 
                         datatime = np.arange(Base1Hora.shape[0]), 
                         var_names=var_names)

# %%
dataframe

# %%
parcorr = ParCorr(significance='analytic')
pcmci = PCMCI(
    dataframe=dataframe, 
    cond_ind_test=parcorr,
    verbosity=1)

# %%
correlations = pcmci.get_lagged_dependencies(tau_max=60)
lag_func_matrix = tp.plot_lagfuncs(val_matrix=correlations, setup_args={'var_names':var_names, 
                                    'x_base':5, 'y_base':.5})
# Out:
# ## Estimating lagged dependencies

# %%
pcmci.verbosity = 1
results = pcmci.run_pcmci(tau_max=60, pc_alpha=None)
# Out:
# ##
# ## Running Tigramite PC algorithm
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 60
# pc_alpha = None
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Variable PresionDesc
#
# ## Variable Potencia
#
# ## Variable Medios
#
# ## Variable Gruesos
#
# ## Resulting condition sets:
#
#     Variable PresionDesc has 26 parent(s):
#     [pc_alpha = 0.5]
#         (PresionDesc -1): max_pval = 0.00000, min_val = 0.578
#         (PresionDesc -5): max_pval = 0.00000, min_val = 0.342
#         (Potencia -7): max_pval = 0.03953, min_val = 0.080
#         (Potencia -22): max_pval = 0.04808, min_val = 0.077
#         (PresionDesc -33): max_pval = 0.05518, min_val = 0.076
#         (Potencia -54): max_pval = 0.08458, min_val = 0.068
#         (Gruesos -60): max_pval = 0.13758, min_val = 0.058
#         (PresionDesc -22): max_pval = 0.15600, min_val = 0.056
#         (PresionDesc -6): max_pval = 0.19618, min_val = 0.051
#         (Gruesos -37): max_pval = 0.22669, min_val = 0.048
#         (Medios -17): max_pval = 0.22875, min_val = 0.048
#         (Gruesos -48): max_pval = 0.26780, min_val = 0.044
#         (Medios -1): max_pval = 0.26057, min_val = 0.044
#         (Medios -44): max_pval = 0.28507, min_val = 0.043
#         (Potencia -48): max_pval = 0.32045, min_val = 0.040
#         (Gruesos -45): max_pval = 0.34933, min_val = 0.037
#         (Gruesos -56): max_pval = 0.36057, min_val = 0.036
#         (PresionDesc -13): max_pval = 0.40538, min_val = 0.033
#         (Potencia -3): max_pval = 0.40460, min_val = 0.033
#         (Medios -55): max_pval = 0.41795, min_val = 0.032
#         (Gruesos -17): max_pval = 0.42107, min_val = 0.032
#         (Medios -4): max_pval = 0.42769, min_val = 0.031
#         (Medios -33): max_pval = 0.43517, min_val = 0.031
#         (Gruesos -57): max_pval = 0.46612, min_val = 0.029
#         (PresionDesc -10): max_pval = 0.46117, min_val = 0.029
#         (Potencia -26): max_pval = 0.48020, min_val = 0.028
#
#     Variable Potencia has 33 parent(s):
#     [pc_alpha = 0.5]
#         (Potencia -1): max_pval = 0.00000, min_val = 0.543
#         (Potencia -5): max_pval = 0.00005, min_val = 0.158
#         (Potencia -3): max_pval = 0.01581, min_val = 0.095
#         (Gruesos -1): max_pval = 0.03550, min_val = 0.084
#         (Gruesos -37): max_pval = 0.05200, min_val = 0.076
#         (Medios -32): max_pval = 0.05418, min_val = 0.076
#         (Potencia -23): max_pval = 0.10197, min_val = 0.065
#         (PresionDesc -24): max_pval = 0.11229, min_val = 0.063
#         (PresionDesc -1): max_pval = 0.13576, min_val = 0.059
#         (Medios -1): max_pval = 0.14139, min_val = 0.058
#         (Medios -21): max_pval = 0.17837, min_val = 0.053
#         (Medios -18): max_pval = 0.19290, min_val = 0.051
#         (PresionDesc -3): max_pval = 0.19993, min_val = 0.050
#         (Potencia -2): max_pval = 0.21505, min_val = 0.049
#         (Potencia -46): max_pval = 0.24013, min_val = 0.047
#         (Gruesos -14): max_pval = 0.23817, min_val = 0.046
#         (Gruesos -6): max_pval = 0.23944, min_val = 0.046
#         (PresionDesc -10): max_pval = 0.26724, min_val = 0.043
#         (PresionDesc -12): max_pval = 0.29548, min_val = 0.041
#         (PresionDesc -50): max_pval = 0.33132, min_val = 0.038
#         (Potencia -10): max_pval = 0.33676, min_val = 0.038
#         (Potencia -42): max_pval = 0.35892, min_val = 0.036
#         (Potencia -35): max_pval = 0.39075, min_val = 0.034
#         (PresionDesc -41): max_pval = 0.41564, min_val = 0.032
#         (PresionDesc -54): max_pval = 0.42708, min_val = 0.031
#         (Gruesos -26): max_pval = 0.45824, min_val = 0.030
#         (Medios -34): max_pval = 0.44918, min_val = 0.030
#         (Gruesos -43): max_pval = 0.45094, min_val = 0.030
#         (Gruesos -36): max_pval = 0.45809, min_val = 0.029
#         (Gruesos -53): max_pval = 0.47270, min_val = 0.029
#         (PresionDesc -60): max_pval = 0.48523, min_val = 0.028
#         (Potencia -56): max_pval = 0.48000, min_val = 0.028
#         (PresionDesc -47): max_pval = 0.49905, min_val = 0.027
#
#     Variable Medios has 28 parent(s):
#     [pc_alpha = 0.5]
#         (Medios -1): max_pval = 0.00000, min_val = 0.802
#         (Medios -2): max_pval = 0.00000, min_val = 0.407
#         (Medios -3): max_pval = 0.00021, min_val = 0.145
#         (PresionDesc -14): max_pval = 0.02505, min_val = 0.088
#         (Medios -4): max_pval = 0.03237, min_val = 0.084
#         (Gruesos -35): max_pval = 0.04190, min_val = 0.080
#         (Medios -28): max_pval = 0.06468, min_val = 0.072
#         (Gruesos -22): max_pval = 0.08373, min_val = 0.069
#         (PresionDesc -37): max_pval = 0.11509, min_val = 0.062
#         (Medios -21): max_pval = 0.16657, min_val = 0.054
#         (Medios -56): max_pval = 0.17265, min_val = 0.054
#         (Potencia -50): max_pval = 0.29214, min_val = 0.041
#         (Potencia -19): max_pval = 0.29441, min_val = 0.041
#         (Gruesos -16): max_pval = 0.31815, min_val = 0.039
#         (Medios -5): max_pval = 0.32548, min_val = 0.039
#         (PresionDesc -41): max_pval = 0.32847, min_val = 0.038
#         (Potencia -53): max_pval = 0.37278, min_val = 0.035
#         (Gruesos -48): max_pval = 0.37365, min_val = 0.035
#         (Medios -15): max_pval = 0.38941, min_val = 0.034
#         (Potencia -59): max_pval = 0.39077, min_val = 0.034
#         (Medios -57): max_pval = 0.39737, min_val = 0.033
#         (Gruesos -44): max_pval = 0.39545, min_val = 0.033
#         (Potencia -30): max_pval = 0.41539, min_val = 0.032
#         (Potencia -47): max_pval = 0.45221, min_val = 0.029
#         (Potencia -8): max_pval = 0.45964, min_val = 0.029
#         (Potencia -23): max_pval = 0.46650, min_val = 0.029
#         (Potencia -4): max_pval = 0.47855, min_val = 0.028
#         (Gruesos -10): max_pval = 0.48629, min_val = 0.028
#
#     Variable Gruesos has 22 parent(s):
#     [pc_alpha = 0.5]
#         (Gruesos -1): max_pval = 0.00000, min_val = 0.682
#         (Gruesos -2): max_pval = 0.00000, min_val = 0.277
#         (Gruesos -5): max_pval = 0.00000, min_val = 0.224
#         (Gruesos -3): max_pval = 0.00065, min_val = 0.133
#         (Gruesos -4): max_pval = 0.03809, min_val = 0.081
#         (PresionDesc -5): max_pval = 0.09199, min_val = 0.066
#         (PresionDesc -53): max_pval = 0.15294, min_val = 0.057
#         (Gruesos -15): max_pval = 0.18857, min_val = 0.052
#         (Potencia -35): max_pval = 0.19511, min_val = 0.051
#         (Gruesos -7): max_pval = 0.23449, min_val = 0.046
#         (Potencia -41): max_pval = 0.24032, min_val = 0.046
#         (PresionDesc -23): max_pval = 0.25838, min_val = 0.045
#         (Gruesos -25): max_pval = 0.26299, min_val = 0.044
#         (Potencia -2): max_pval = 0.27106, min_val = 0.043
#         (Medios -37): max_pval = 0.28686, min_val = 0.042
#         (Medios -44): max_pval = 0.30161, min_val = 0.040
#         (Potencia -53): max_pval = 0.37799, min_val = 0.035
#         (Medios -1): max_pval = 0.40020, min_val = 0.033
#         (Medios -53): max_pval = 0.42870, min_val = 0.031
#         (Gruesos -30): max_pval = 0.42971, min_val = 0.031
#         (PresionDesc -15): max_pval = 0.46163, min_val = 0.029
#         (PresionDesc -14): max_pval = 0.48039, min_val = 0.028
#
# ##
# ## Running Tigramite MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 60
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable PresionDesc has 28 link(s):
#         (PresionDesc -1): pval = 0.00000 | val = 0.573 | conf = (0.000, 0.000)
#         (PresionDesc -5): pval = 0.00000 | val = -0.516 | conf = (0.000, 0.000)
#         (PresionDesc -10): pval = 0.00000 | val = -0.407 | conf = (0.000, 0.000)
#         (PresionDesc -6): pval = 0.00000 | val = 0.288 | conf = (0.000, 0.000)
#         (PresionDesc -11): pval = 0.00000 | val = 0.257 | conf = (0.000, 0.000)
#         (Potencia 0): pval = 0.00000 | val = -0.206 | conf = (0.000, 0.000)
#         (PresionDesc -15): pval = 0.00092 | val = -0.134 | conf = (0.000, 0.000)
#         (Potencia -13): pval = 0.00229 | val = -0.124 | conf = (0.000, 0.000)
#         (Potencia -11): pval = 0.00355 | val = -0.119 | conf = (0.000, 0.000)
#         (PresionDesc -22): pval = 0.00380 | val = 0.117 | conf = (0.000, 0.000)
#         (Potencia -22): pval = 0.00537 | val = 0.114 | conf = (0.000, 0.000)
#         (Medios 0): pval = 0.00569 | val = 0.112 | conf = (0.000, 0.000)
#         (Potencia -16): pval = 0.00758 | val = 0.109 | conf = (0.000, 0.000)
#         (Potencia -7): pval = 0.00831 | val = -0.108 | conf = (0.000, 0.000)
#         (Gruesos -24): pval = 0.01211 | val = -0.102 | conf = (0.000, 0.000)
#         (PresionDesc -37): pval = 0.01633 | val = -0.098 | conf = (0.000, 0.000)
#         (Gruesos 0): pval = 0.01637 | val = -0.097 | conf = (0.000, 0.000)
#         (Gruesos -59): pval = 0.01843 | val = -0.095 | conf = (0.000, 0.000)
#         (Gruesos -35): pval = 0.01970 | val = -0.094 | conf = (0.000, 0.000)
#         (Potencia -44): pval = 0.02402 | val = -0.092 | conf = (0.000, 0.000)
#         (Gruesos -33): pval = 0.02465 | val = -0.091 | conf = (0.000, 0.000)
#         (Potencia -38): pval = 0.02709 | val = -0.090 | conf = (0.000, 0.000)
#         (Medios -6): pval = 0.02773 | val = 0.090 | conf = (0.000, 0.000)
#         (Potencia -33): pval = 0.03752 | val = 0.085 | conf = (0.000, 0.000)
#         (PresionDesc -40): pval = 0.03962 | val = -0.084 | conf = (0.000, 0.000)
#         (Gruesos -23): pval = 0.04407 | val = 0.082 | conf = (0.000, 0.000)
#         (Medios -10): pval = 0.04801 | val = -0.081 | conf = (0.000, 0.000)
#         (Gruesos -54): pval = 0.04916 | val = -0.080 | conf = (0.000, 0.000)
#
#     Variable Potencia has 26 link(s):
#         (Potencia -1): pval = 0.00000 | val = 0.622 | conf = (0.000, 0.000)
#         (Potencia -5): pval = 0.00000 | val = -0.415 | conf = (0.000, 0.000)
#         (Potencia -6): pval = 0.00000 | val = 0.344 | conf = (0.000, 0.000)
#         (Potencia -7): pval = 0.00000 | val = 0.289 | conf = (0.000, 0.000)
#         (Potencia -2): pval = 0.00000 | val = 0.259 | conf = (0.000, 0.000)
#         (PresionDesc 0): pval = 0.00000 | val = -0.206 | conf = (0.000, 0.000)
#         (PresionDesc -1): pval = 0.00336 | val = -0.119 | conf = (0.000, 0.000)
#         (Potencia -23): pval = 0.00489 | val = -0.115 | conf = (0.000, 0.000)
#         (Medios -59): pval = 0.00602 | val = 0.112 | conf = (0.000, 0.000)
#         (Potencia -8): pval = 0.00856 | val = 0.108 | conf = (0.000, 0.000)
#         (Potencia -31): pval = 0.00889 | val = -0.107 | conf = (0.000, 0.000)
#         (Potencia -3): pval = 0.00928 | val = -0.107 | conf = (0.000, 0.000)
#         (PresionDesc -5): pval = 0.00906 | val = 0.107 | conf = (0.000, 0.000)
#         (Potencia -4): pval = 0.01174 | val = 0.103 | conf = (0.000, 0.000)
#         (Gruesos -9): pval = 0.01448 | val = 0.100 | conf = (0.000, 0.000)
#         (Medios -4): pval = 0.01569 | val = 0.099 | conf = (0.000, 0.000)
#         (Medios -46): pval = 0.02049 | val = 0.095 | conf = (0.000, 0.000)
#         (Gruesos -4): pval = 0.02316 | val = -0.093 | conf = (0.000, 0.000)
#         (Gruesos -8): pval = 0.02326 | val = -0.092 | conf = (0.000, 0.000)
#         (Potencia -56): pval = 0.02722 | val = -0.091 | conf = (0.000, 0.000)
#         (Potencia -13): pval = 0.02865 | val = 0.090 | conf = (0.000, 0.000)
#         (Potencia -51): pval = 0.03035 | val = 0.089 | conf = (0.000, 0.000)
#         (Gruesos -18): pval = 0.03481 | val = 0.086 | conf = (0.000, 0.000)
#         (Gruesos -52): pval = 0.03505 | val = -0.086 | conf = (0.000, 0.000)
#         (PresionDesc -41): pval = 0.03770 | val = -0.085 | conf = (0.000, 0.000)
#         (Medios -1): pval = 0.04102 | val = 0.084 | conf = (0.000, 0.000)
#
#     Variable Medios has 31 link(s):
#         (Medios -1): pval = 0.00000 | val = 0.830 | conf = (0.000, 0.000)
#         (Medios -2): pval = 0.00000 | val = -0.533 | conf = (0.000, 0.000)
#         (Medios -3): pval = 0.00000 | val = 0.434 | conf = (0.000, 0.000)
#         (Medios -10): pval = 0.00000 | val = -0.363 | conf = (0.000, 0.000)
#         (Medios -4): pval = 0.00000 | val = -0.344 | conf = (0.000, 0.000)
#         (Medios -11): pval = 0.00144 | val = 0.130 | conf = (0.000, 0.000)
#         (PresionDesc -44): pval = 0.00362 | val = 0.118 | conf = (0.000, 0.000)
#         (PresionDesc -40): pval = 0.00386 | val = 0.117 | conf = (0.000, 0.000)
#         (PresionDesc 0): pval = 0.00569 | val = 0.112 | conf = (0.000, 0.000)
#         (Gruesos 0): pval = 0.00649 | val = -0.110 | conf = (0.000, 0.000)
#         (Potencia -27): pval = 0.00755 | val = 0.109 | conf = (0.000, 0.000)
#         (Medios -21): pval = 0.00889 | val = -0.107 | conf = (0.000, 0.000)
#         (Gruesos -22): pval = 0.01441 | val = 0.099 | conf = (0.000, 0.000)
#         (PresionDesc -14): pval = 0.01518 | val = 0.099 | conf = (0.000, 0.000)
#         (Potencia -19): pval = 0.02138 | val = 0.094 | conf = (0.000, 0.000)
#         (PresionDesc -4): pval = 0.02043 | val = -0.094 | conf = (0.000, 0.000)
#         (Medios -7): pval = 0.02209 | val = 0.093 | conf = (0.000, 0.000)
#         (PresionDesc -37): pval = 0.02242 | val = 0.093 | conf = (0.000, 0.000)
#         (PresionDesc -43): pval = 0.02313 | val = 0.092 | conf = (0.000, 0.000)
#         (PresionDesc -35): pval = 0.02429 | val = 0.092 | conf = (0.000, 0.000)
#         (Medios -52): pval = 0.02628 | val = -0.091 | conf = (0.000, 0.000)
#         (PresionDesc -50): pval = 0.02788 | val = -0.090 | conf = (0.000, 0.000)
#         (PresionDesc -58): pval = 0.03035 | val = -0.088 | conf = (0.000, 0.000)
#         (PresionDesc -16): pval = 0.03118 | val = -0.088 | conf = (0.000, 0.000)
#         (Gruesos -8): pval = 0.03150 | val = -0.087 | conf = (0.000, 0.000)
#         (Potencia -43): pval = 0.03600 | val = -0.086 | conf = (0.000, 0.000)
#         (PresionDesc -41): pval = 0.03773 | val = -0.085 | conf = (0.000, 0.000)
#         (Medios -22): pval = 0.04173 | val = 0.083 | conf = (0.000, 0.000)
#         (PresionDesc -45): pval = 0.04268 | val = -0.083 | conf = (0.000, 0.000)
#         (Medios -5): pval = 0.04696 | val = 0.081 | conf = (0.000, 0.000)
#         (Gruesos -48): pval = 0.04764 | val = -0.080 | conf = (0.000, 0.000)
#
#     Variable Gruesos has 13 link(s):
#         (Gruesos -1): pval = 0.00000 | val = 0.786 | conf = (0.000, 0.000)
#         (Gruesos -2): pval = 0.00000 | val = -0.536 | conf = (0.000, 0.000)
#         (Gruesos -3): pval = 0.00000 | val = 0.473 | conf = (0.000, 0.000)
#         (Gruesos -4): pval = 0.00000 | val = -0.381 | conf = (0.000, 0.000)
#         (Gruesos -10): pval = 0.00000 | val = -0.340 | conf = (0.000, 0.000)
#         (Medios 0): pval = 0.00649 | val = -0.110 | conf = (0.000, 0.000)
#         (Potencia -2): pval = 0.00750 | val = 0.109 | conf = (0.000, 0.000)
#         (Gruesos -7): pval = 0.00988 | val = 0.104 | conf = (0.000, 0.000)
#         (PresionDesc 0): pval = 0.01637 | val = -0.097 | conf = (0.000, 0.000)
#         (Medios -7): pval = 0.01683 | val = -0.097 | conf = (0.000, 0.000)
#         (Medios -10): pval = 0.01885 | val = 0.095 | conf = (0.000, 0.000)
#         (Medios -5): pval = 0.03274 | val = -0.087 | conf = (0.000, 0.000)
#         (Gruesos -55): pval = 0.04544 | val = -0.081 | conf = (0.000, 0.000)

# %%
q_matrix = pcmci.get_corrected_pvalues(p_matrix=results['p_matrix'], fdr_method='fdr_bh')
pcmci.print_significant_links(
        p_matrix = results['p_matrix'], 
        q_matrix = q_matrix,
        val_matrix = results['val_matrix'],
       alpha_level = 0.01)
# Out:
# ## Significant links at alpha = 0.01:
#
#     Variable PresionDesc has 7 link(s):
#         (PresionDesc -1): pval = 0.00000 | qval = 0.00000 | val = 0.573
#         (PresionDesc -5): pval = 0.00000 | qval = 0.00000 | val = -0.516
#         (PresionDesc -10): pval = 0.00000 | qval = 0.00000 | val = -0.407
#         (PresionDesc -6): pval = 0.00000 | qval = 0.00000 | val = 0.288
#         (PresionDesc -11): pval = 0.00000 | qval = 0.00000 | val = 0.257
#         (Potencia 0): pval = 0.00000 | qval = 0.00000 | val = -0.206
#         (Medios 0): pval = 0.00569 | qval = 0.00569 | val = 0.112
#
#     Variable Potencia has 6 link(s):
#         (Potencia -1): pval = 0.00000 | qval = 0.00000 | val = 0.622
#         (Potencia -5): pval = 0.00000 | qval = 0.00000 | val = -0.415
#         (Potencia -6): pval = 0.00000 | qval = 0.00000 | val = 0.344
#         (Potencia -7): pval = 0.00000 | qval = 0.00000 | val = 0.289
#         (Potencia -2): pval = 0.00000 | qval = 0.00000 | val = 0.259
#         (PresionDesc 0): pval = 0.00000 | qval = 0.00000 | val = -0.206
#
#     Variable Medios has 7 link(s):
#         (Medios -1): pval = 0.00000 | qval = 0.00000 | val = 0.830
#         (Medios -2): pval = 0.00000 | qval = 0.00000 | val = -0.533
#         (Medios -3): pval = 0.00000 | qval = 0.00000 | val = 0.434
#         (Medios -10): pval = 0.00000 | qval = 0.00000 | val = -0.363
#         (Medios -4): pval = 0.00000 | qval = 0.00000 | val = -0.344
#         (PresionDesc 0): pval = 0.00569 | qval = 0.00569 | val = 0.112
#         (Gruesos 0): pval = 0.00649 | qval = 0.00649 | val = -0.110
#
#     Variable Gruesos has 6 link(s):
#         (Gruesos -1): pval = 0.00000 | qval = 0.00000 | val = 0.786
#         (Gruesos -2): pval = 0.00000 | qval = 0.00000 | val = -0.536
#         (Gruesos -3): pval = 0.00000 | qval = 0.00000 | val = 0.473
#         (Gruesos -4): pval = 0.00000 | qval = 0.00000 | val = -0.381
#         (Gruesos -10): pval = 0.00000 | qval = 0.00000 | val = -0.340
#         (Medios 0): pval = 0.00649 | qval = 0.00649 | val = -0.110

# %%
link_matrix = pcmci.return_significant_parents(pq_matrix=q_matrix,
                        val_matrix=results['val_matrix'], alpha_level=0.01)['link_matrix']

# %%
link_matrix
# Out:
# array([[[False,  True, False, False, False,  True,  True, False, False,
#          False,  True,  True, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False],
#         [ True, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False],
#         [ True, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False]],
#
#        [[ True, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False],
#         [False,  True,  True, False, False,  True,  True,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False]],
#
#        [[ True, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False],
#         [False,  True,  True,  True,  True, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False],
#         [ True, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False]],
#
#        [[False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False],
#         [ True, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False],
#         [False,  True,  True,  True,  True, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False]]])

# %%
tp.plot_graph(
    val_matrix=results['val_matrix'],
    link_matrix=link_matrix,
    var_names=var_names,
    link_colorbar_label='cross-MCI',
    node_colorbar_label='auto-MCI',
    )
# Out:
# (<Figure size 432x288 with 3 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f703ffef898>)

# %%
tp.plot_time_series_graph(
    val_matrix=results['val_matrix'],
    link_matrix=link_matrix,
    var_names=var_names,
    link_colorbar_label='MCI',
    )

# %%
pcmci_parcorr = PCMCI(
    dataframe=dataframe, 
    cond_ind_test=parcorr,
    verbosity=0)
results = pcmci_parcorr.run_pcmci(tau_max=2, pc_alpha=0.2)
pcmci_parcorr.print_significant_links(
        p_matrix = results['p_matrix'], 
        val_matrix = results['val_matrix'],
        alpha_level = 0.1)
# Out:
# ## Significant links at alpha = 0.1:
#
#     Variable PresionDesc has 5 link(s):
#         (PresionDesc -1): pval = 0.00000 | val = 0.620
#         (Potencia 0): pval = 0.00000 | val = -0.200
#         (Gruesos -2): pval = 0.01199 | val = -0.091
#         (Medios -1): pval = 0.06821 | val = 0.066
#         (Medios 0): pval = 0.08028 | val = 0.063
#
#     Variable Potencia has 8 link(s):
#         (Potencia -1): pval = 0.00000 | val = 0.609
#         (PresionDesc 0): pval = 0.00000 | val = -0.200
#         (Potencia -2): pval = 0.00000 | val = 0.180
#         (PresionDesc -1): pval = 0.00044 | val = -0.127
#         (Medios -1): pval = 0.02608 | val = 0.080
#         (Medios 0): pval = 0.05839 | val = 0.068
#         (Gruesos -1): pval = 0.08251 | val = 0.063
#         (Gruesos 0): pval = 0.09396 | val = -0.061
#
#     Variable Medios has 6 link(s):
#         (Medios -1): pval = 0.00000 | val = 0.800
#         (Medios -2): pval = 0.00000 | val = -0.535
#         (Gruesos -1): pval = 0.00971 | val = -0.093
#         (Gruesos 0): pval = 0.02395 | val = -0.082
#         (Potencia 0): pval = 0.05839 | val = 0.068
#         (PresionDesc 0): pval = 0.08028 | val = 0.063
#
#     Variable Gruesos has 6 link(s):
#         (Gruesos -1): pval = 0.00000 | val = 0.735
#         (Gruesos -2): pval = 0.00000 | val = -0.588
#         (Potencia -2): pval = 0.00554 | val = 0.100
#         (Medios 0): pval = 0.02395 | val = -0.082
#         (PresionDesc -1): pval = 0.03623 | val = -0.076
#         (Potencia 0): pval = 0.09396 | val = -0.061

# %%
gpdc = GPDC(significance='analytic', gp_params=None)
# gpdc.generate_and_save_nulldists(sample_sizes=range(495, 501),
#     null_dist_filename='dc_nulldists.npz')
gpdc.null_dist_filename ='dc_nulldists.npz'
pcmci_gpdc = PCMCI(
    dataframe=dataframe, 
    cond_ind_test=gpdc,
    verbosity=0)

# %%
results = pcmci_gpdc.run_pcmci(tau_max=2, pc_alpha=0.1)
pcmci_gpdc.print_significant_links(
        p_matrix = results['p_matrix'], 
        val_matrix = results['val_matrix'],
        alpha_level = 0.1)
# Out:
# ## Significant links at alpha = 0.1:
#
#     Variable PresionDesc has 3 link(s):
#         (PresionDesc -1): pval = 0.00000 | val = 0.288
#         (Potencia 0): pval = 0.00000 | val = 0.027
#         (Gruesos -2): pval = 0.01300 | val = 0.010
#
#     Variable Potencia has 9 link(s):
#         (Potencia -1): pval = 0.00000 | val = 0.279
#         (PresionDesc 0): pval = 0.00000 | val = 0.027
#         (Potencia -2): pval = 0.00100 | val = 0.016
#         (PresionDesc -1): pval = 0.00100 | val = 0.015
#         (Gruesos -2): pval = 0.04300 | val = 0.007
#         (PresionDesc -2): pval = 0.06600 | val = 0.006
#         (Gruesos -1): pval = 0.06800 | val = 0.006
#         (Medios -1): pval = 0.08400 | val = 0.006
#         (Medios 0): pval = 0.10000 | val = 0.006
#
#     Variable Medios has 4 link(s):
#         (Medios -1): pval = 0.00000 | val = 0.563
#         (Medios -2): pval = 0.00000 | val = 0.218
#         (Gruesos -1): pval = 0.06200 | val = 0.006
#         (Potencia 0): pval = 0.10000 | val = 0.006
#
#     Variable Gruesos has 5 link(s):
#         (Gruesos -1): pval = 0.00000 | val = 0.431
#         (Gruesos -2): pval = 0.00000 | val = 0.295
#         (Potencia -2): pval = 0.00200 | val = 0.014
#         (PresionDesc -1): pval = 0.03300 | val = 0.007
#         (PresionDesc -2): pval = 0.06400 | val = 0.006

# %%
cmi_knn = CMIknn(significance='shuffle_test', knn=0.1, shuffle_neighbors=5)
pcmci_cmi_knn = PCMCI(
    dataframe=dataframe, 
    cond_ind_test=cmi_knn,
    verbosity=2)
results = pcmci_cmi_knn.run_pcmci(tau_max=2, pc_alpha=0.05)
pcmci_cmi_knn.print_significant_links(
        p_matrix = results['p_matrix'], 
        val_matrix = results['val_matrix'],
        alpha_level = 0.01)
# Out:
# ##
# ## Running Tigramite PC algorithm
# ##
#
# Parameters:
# independence test = cmi_knn
# tau_min = 1
# tau_max = 2
# pc_alpha = 0.05
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Variable PresionDesc
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link (PresionDesc -1) --> PresionDesc (1/8):
#     Combination 0:  --> pval = 0.29500 / val = 0.004
#     Non-significance detected.
#
#     Link (PresionDesc -2) --> PresionDesc (2/8):
#     Combination 0:  --> pval = 0.27500 / val = 0.003
#     Non-significance detected.
#
#     Link (Gruesos -1) --> PresionDesc (3/8):
#     Combination 0:  --> pval = 0.60500 / val = -0.003
#     Non-significance detected.
#
#     Link (Gruesos -2) --> PresionDesc (4/8):
#     Combination 0:  --> pval = 0.01400 / val = 0.021
#     No conditions of dimension 0 left.
#
#     Link (Medios -1) --> PresionDesc (5/8):
#     Combination 0:  --> pval = 0.59800 / val = -0.003
#     Non-significance detected.
#
#     Link (Medios -2) --> PresionDesc (6/8):
#     Combination 0:  --> pval = 0.91900 / val = -0.011
#     Non-significance detected.
#
#     Link (Potencia -1) --> PresionDesc (7/8):
#     Combination 0:  --> pval = 0.54700 / val = -0.002
#     Non-significance detected.
#
#     Link (Potencia -2) --> PresionDesc (8/8):
#     Combination 0:  --> pval = 0.91600 / val = -0.011
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |I_{ij}(tau)|
#
# Updating parents:
#
#     Variable PresionDesc has 1 parent(s):
#         (Gruesos -2): max_pval = 0.01400, min_val = 0.021
#
# Algorithm converged for variable PresionDesc
#
# ## Variable Gruesos
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link (PresionDesc -1) --> Gruesos (1/8):
#     Combination 0:  --> pval = 0.88000 / val = -0.010
#     Non-significance detected.
#
#     Link (PresionDesc -2) --> Gruesos (2/8):
#     Combination 0:  --> pval = 0.46100 / val = -0.000
#     Non-significance detected.
#
#     Link (Gruesos -1) --> Gruesos (3/8):
#     Combination 0:  --> pval = 0.06800 / val = 0.016
#     Non-significance detected.
#
#     Link (Gruesos -2) --> Gruesos (4/8):
#     Combination 0:  --> pval = 0.00000 / val = 0.070
#     No conditions of dimension 0 left.
#
#     Link (Medios -1) --> Gruesos (5/8):
#     Combination 0:  --> pval = 0.84900 / val = -0.008
#     Non-significance detected.
#
#     Link (Medios -2) --> Gruesos (6/8):
#     Combination 0:  --> pval = 0.14100 / val = 0.009
#     Non-significance detected.
#
#     Link (Potencia -1) --> Gruesos (7/8):
#     Combination 0:  --> pval = 0.81700 / val = -0.008
#     Non-significance detected.
#
#     Link (Potencia -2) --> Gruesos (8/8):
#     Combination 0:  --> pval = 0.90000 / val = -0.011
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |I_{ij}(tau)|
#
# Updating parents:
#
#     Variable Gruesos has 1 parent(s):
#         (Gruesos -2): max_pval = 0.00000, min_val = 0.070
#
# Algorithm converged for variable Gruesos
#
# ## Variable Medios
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link (PresionDesc -1) --> Medios (1/8):
#     Combination 0:  --> pval = 0.80300 / val = -0.007
#     Non-significance detected.
#
#     Link (PresionDesc -2) --> Medios (2/8):
#     Combination 0:  --> pval = 0.74200 / val = -0.006
#     Non-significance detected.
#
#     Link (Gruesos -1) --> Medios (3/8):
#     Combination 0:  --> pval = 0.77400 / val = -0.006
#     Non-significance detected.
#
#     Link (Gruesos -2) --> Medios (4/8):
#     Combination 0:  --> pval = 0.68500 / val = -0.005
#     Non-significance detected.
#
#     Link (Medios -1) --> Medios (5/8):
#     Combination 0:  --> pval = 0.00300 / val = 0.033
#     No conditions of dimension 0 left.
#
#     Link (Medios -2) --> Medios (6/8):
#     Combination 0:  --> pval = 0.54700 / val = -0.001
#     Non-significance detected.
#
#     Link (Potencia -1) --> Medios (7/8):
#     Combination 0:  --> pval = 0.62400 / val = -0.004
#     Non-significance detected.
#
#     Link (Potencia -2) --> Medios (8/8):
#     Combination 0:  --> pval = 0.20200 / val = 0.006
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |I_{ij}(tau)|
#
# Updating parents:
#
#     Variable Medios has 1 parent(s):
#         (Medios -1): max_pval = 0.00300, min_val = 0.033
#
# Algorithm converged for variable Medios
#
# ## Variable Potencia
#
# Iterating through pc_alpha = [0.05]:
#
# # pc_alpha = 0.05 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link (PresionDesc -1) --> Potencia (1/8):
#     Combination 0:  --> pval = 0.95700 / val = -0.012
#     Non-significance detected.
#
#     Link (PresionDesc -2) --> Potencia (2/8):
#     Combination 0:  --> pval = 0.99200 / val = -0.019
#     Non-significance detected.
#
#     Link (Gruesos -1) --> Potencia (3/8):
#     Combination 0:  --> pval = 0.72500 / val = -0.006
#     Non-significance detected.
#
#     Link (Gruesos -2) --> Potencia (4/8):
#     Combination 0:  --> pval = 0.84000 / val = -0.008
#     Non-significance detected.
#
#     Link (Medios -1) --> Potencia (5/8):
#     Combination 0:  --> pval = 0.38900 / val = 0.001
#     Non-significance detected.
#
#     Link (Medios -2) --> Potencia (6/8):
#     Combination 0:  --> pval = 0.09200 / val = 0.010
#     Non-significance detected.
#
#     Link (Potencia -1) --> Potencia (7/8):
#     Combination 0:  --> pval = 0.47600 / val = 0.001
#     Non-significance detected.
#
#     Link (Potencia -2) --> Potencia (8/8):
#     Combination 0:  --> pval = 0.03300 / val = 0.019
#     No conditions of dimension 0 left.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |I_{ij}(tau)|
#
# Updating parents:
#
#     Variable Potencia has 1 parent(s):
#         (Potencia -2): max_pval = 0.03300, min_val = 0.019
#
# Algorithm converged for variable Potencia
#
# ## Resulting condition sets:
#
#     Variable PresionDesc has 1 parent(s):
#         (Gruesos -2): max_pval = 0.01400, min_val = 0.021
#
#     Variable Gruesos has 1 parent(s):
#         (Gruesos -2): max_pval = 0.00000, min_val = 0.070
#
#     Variable Medios has 1 parent(s):
#         (Medios -1): max_pval = 0.00300, min_val = 0.033
#
#     Variable Potencia has 1 parent(s):
#         (Potencia -2): max_pval = 0.03300, min_val = 0.019
#
# ##
# ## Running Tigramite MCI algorithm
# ##
#
# Parameters:
#
# independence test = cmi_knn
# tau_min = 0
# tau_max = 2
# max_conds_py = None
# max_conds_px = None
#
#         link (PresionDesc -1) --> PresionDesc (1/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Gruesos -3) ]
#         pval = 0.03600 | val = 0.010
#
#         link (PresionDesc -2) --> PresionDesc (2/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Gruesos -4) ]
#         pval = 0.33300 | val = 0.000
#
#         link (Gruesos 0) --> PresionDesc (3/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Gruesos -2) ]
#         pval = 0.52000 | val = -0.001
#
#         link (Gruesos -1) --> PresionDesc (4/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Gruesos -3) ]
#         pval = 0.58700 | val = -0.003
#
#         link (Gruesos -2) --> PresionDesc (5/11):
#         with conds_y = [ ]
#         with conds_x = [ (Gruesos -4) ]
#         pval = 0.00300 | val = 0.018
#
#         link (Medios 0) --> PresionDesc (6/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Medios -1) ]
#         pval = 0.82700 | val = -0.005
#
#         link (Medios -1) --> PresionDesc (7/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Medios -2) ]
#         pval = 0.30700 | val = 0.000
#
#         link (Medios -2) --> PresionDesc (8/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Medios -3) ]
#         pval = 0.20200 | val = 0.005
#
#         link (Potencia 0) --> PresionDesc (9/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Potencia -2) ]
#         pval = 0.00600 | val = 0.016
#
#         link (Potencia -1) --> PresionDesc (10/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Potencia -3) ]
#         pval = 0.15200 | val = 0.008
#
#         link (Potencia -2) --> PresionDesc (11/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Potencia -4) ]
#         pval = 0.82600 | val = -0.007
#
#         link (PresionDesc 0) --> Gruesos (1/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Gruesos -2) ]
#         pval = 0.48500 | val = -0.002
#
#         link (PresionDesc -1) --> Gruesos (2/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Gruesos -3) ]
#         pval = 0.74900 | val = -0.003
#
#         link (PresionDesc -2) --> Gruesos (3/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Gruesos -4) ]
#         pval = 0.39600 | val = 0.003
#
#         link (Gruesos -1) --> Gruesos (4/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Gruesos -3) ]
#         pval = 0.00000 | val = 0.020
#
#         link (Gruesos -2) --> Gruesos (5/11):
#         with conds_y = [ ]
#         with conds_x = [ (Gruesos -4) ]
#         pval = 0.00000 | val = 0.078
#
#         link (Medios 0) --> Gruesos (6/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Medios -1) ]
#         pval = 0.05900 | val = 0.009
#
#         link (Medios -1) --> Gruesos (7/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Medios -2) ]
#         pval = 0.25100 | val = 0.002
#
#         link (Medios -2) --> Gruesos (8/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Medios -3) ]
#         pval = 0.58000 | val = -0.003
#
#         link (Potencia 0) --> Gruesos (9/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Potencia -2) ]
#         pval = 0.87000 | val = -0.006
#
#         link (Potencia -1) --> Gruesos (10/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Potencia -3) ]
#         pval = 0.93300 | val = -0.006
#
#         link (Potencia -2) --> Gruesos (11/11):
#         with conds_y = [ (Gruesos -2) ]
#         with conds_x = [ (Potencia -4) ]
#         pval = 0.66000 | val = 0.001
#
#         link (PresionDesc 0) --> Medios (1/11):
#         with conds_y = [ (Medios -1) ]
#         with conds_x = [ (Gruesos -2) ]
#         pval = 0.78800 | val = -0.005
#
#         link (PresionDesc -1) --> Medios (2/11):
#         with conds_y = [ (Medios -1) ]
#         with conds_x = [ (Gruesos -3) ]
#         pval = 0.91400 | val = -0.007
#
#         link (PresionDesc -2) --> Medios (3/11):
#         with conds_y = [ (Medios -1) ]
#         with conds_x = [ (Gruesos -4) ]
#         pval = 0.66400 | val = -0.001
#
#         link (Gruesos 0) --> Medios (4/11):
#         with conds_y = [ (Medios -1) ]
#         with conds_x = [ (Gruesos -2) ]
#         pval = 0.03800 | val = 0.009
#
#         link (Gruesos -1) --> Medios (5/11):
#         with conds_y = [ (Medios -1) ]
#         with conds_x = [ (Gruesos -3) ]
#         pval = 0.49600 | val = -0.004
#
#         link (Gruesos -2) --> Medios (6/11):
#         with conds_y = [ (Medios -1) ]
#         with conds_x = [ (Gruesos -4) ]
#         pval = 0.46000 | val = 0.001
#
#         link (Medios -1) --> Medios (7/11):
#         with conds_y = [ ]
#         with conds_x = [ (Medios -2) ]
#         pval = 0.00000 | val = 0.051
#
#         link (Medios -2) --> Medios (8/11):
#         with conds_y = [ (Medios -1) ]
#         with conds_x = [ (Medios -3) ]
#         pval = 0.00000 | val = 0.020
#
#         link (Potencia 0) --> Medios (9/11):
#         with conds_y = [ (Medios -1) ]
#         with conds_x = [ (Potencia -2) ]
#         pval = 0.42300 | val = -0.002
#
#         link (Potencia -1) --> Medios (10/11):
#         with conds_y = [ (Medios -1) ]
#         with conds_x = [ (Potencia -3) ]
#         pval = 0.56100 | val = -0.001
#
#         link (Potencia -2) --> Medios (11/11):
#         with conds_y = [ (Medios -1) ]
#         with conds_x = [ (Potencia -4) ]
#         pval = 0.09200 | val = 0.006
#
#         link (PresionDesc 0) --> Potencia (1/11):
#         with conds_y = [ (Potencia -2) ]
#         with conds_x = [ (Gruesos -2) ]
#         pval = 0.01800 | val = 0.016
#
#         link (PresionDesc -1) --> Potencia (2/11):
#         with conds_y = [ (Potencia -2) ]
#         with conds_x = [ (Gruesos -3) ]
#         pval = 0.81000 | val = -0.003
#
#         link (PresionDesc -2) --> Potencia (3/11):
#         with conds_y = [ (Potencia -2) ]
#         with conds_x = [ (Gruesos -4) ]
#         pval = 0.49900 | val = -0.001
#
#         link (Gruesos 0) --> Potencia (4/11):
#         with conds_y = [ (Potencia -2) ]
#         with conds_x = [ (Gruesos -2) ]
#         pval = 0.96400 | val = -0.008
#
#         link (Gruesos -1) --> Potencia (5/11):
#         with conds_y = [ (Potencia -2) ]
#         with conds_x = [ (Gruesos -3) ]
#         pval = 0.95900 | val = -0.008
#
#         link (Gruesos -2) --> Potencia (6/11):
#         with conds_y = [ (Potencia -2) ]
#         with conds_x = [ (Gruesos -4) ]
#         pval = 0.06400 | val = 0.007
#
#         link (Medios 0) --> Potencia (7/11):
#         with conds_y = [ (Potencia -2) ]
#         with conds_x = [ (Medios -1) ]
#         pval = 0.37100 | val = -0.002
#
#         link (Medios -1) --> Potencia (8/11):
#         with conds_y = [ (Potencia -2) ]
#         with conds_x = [ (Medios -2) ]
#         pval = 0.57800 | val = -0.001
#
#         link (Medios -2) --> Potencia (9/11):
#         with conds_y = [ (Potencia -2) ]
#         with conds_x = [ (Medios -3) ]
#         pval = 0.60500 | val = -0.000
#
#         link (Potencia -1) --> Potencia (10/11):
#         with conds_y = [ (Potencia -2) ]
#         with conds_x = [ (Potencia -3) ]
#         pval = 0.14500 | val = 0.004
#
#         link (Potencia -2) --> Potencia (11/11):
#         with conds_y = [ ]
#         with conds_x = [ (Potencia -4) ]
#         pval = 0.11200 | val = 0.009
#
# ## Significant links at alpha = 0.05:
#
#     Variable PresionDesc has 3 link(s):
#         (Gruesos -2): pval = 0.00300 | val = 0.018 | conf = (0.000, 0.000)
#         (Potencia 0): pval = 0.00600 | val = 0.016 | conf = (0.000, 0.000)
#         (PresionDesc -1): pval = 0.03600 | val = 0.010 | conf = (0.000, 0.000)
#
#     Variable Gruesos has 2 link(s):
#         (Gruesos -2): pval = 0.00000 | val = 0.078 | conf = (0.000, 0.000)
#         (Gruesos -1): pval = 0.00000 | val = 0.020 | conf = (0.000, 0.000)
#
#     Variable Medios has 3 link(s):
#         (Medios -1): pval = 0.00000 | val = 0.051 | conf = (0.000, 0.000)
#         (Medios -2): pval = 0.00000 | val = 0.020 | conf = (0.000, 0.000)
#         (Gruesos 0): pval = 0.03800 | val = 0.009 | conf = (0.000, 0.000)
#
#     Variable Potencia has 1 link(s):
#         (PresionDesc 0): pval = 0.01800 | val = 0.016 | conf = (0.000, 0.000)
#
# ## Significant links at alpha = 0.01:
#
#     Variable PresionDesc has 2 link(s):
#         (Gruesos -2): pval = 0.00300 | val = 0.018
#         (Potencia 0): pval = 0.00600 | val = 0.016
#
#     Variable Gruesos has 2 link(s):
#         (Gruesos -2): pval = 0.00000 | val = 0.078
#         (Gruesos -1): pval = 0.00000 | val = 0.020
#
#     Variable Medios has 2 link(s):
#         (Medios -1): pval = 0.00000 | val = 0.051
#         (Medios -2): pval = 0.00000 | val = 0.020
#
#     Variable Potencia has 0 link(s):

# %%
link_matrix = pcmci_cmi_knn.return_significant_parents(pq_matrix=results['p_matrix'],
                        val_matrix=results['val_matrix'], alpha_level=0.1)['link_matrix']
tp.plot_graph(
    val_matrix=results['val_matrix'],
    link_matrix=link_matrix,
    var_names=var_names,
    link_colorbar_label='cross-MCI',
    node_colorbar_label='auto-MCI',
    vmin_edges=0.,
    vmax_edges = 0.3,
    edge_ticks=0.05,
    cmap_edges='OrRd',
    vmin_nodes=0,
    vmax_nodes=.5,
    node_ticks=.1,
    cmap_nodes='OrRd',
    )
# Out:
# Contemporaneous I(1; 0)=-0.001 != I(0; 1)=-0.002 due to conditions, finite sample effects or masking, here edge color = larger (absolute) value.
# Contemporaneous I(1; 2)=0.009 != I(2; 1)=0.009 due to conditions, finite sample effects or masking, here edge color = larger (absolute) value.
# Contemporaneous I(1; 3)=-0.008 != I(3; 1)=-0.006 due to conditions, finite sample effects or masking, here edge color = larger (absolute) value.
# Contemporaneous I(2; 1)=0.009 != I(1; 2)=0.009 due to conditions, finite sample effects or masking, here edge color = larger (absolute) value.
# Contemporaneous I(3; 2)=-0.002 != I(2; 3)=-0.002 due to conditions, finite sample effects or masking, here edge color = larger (absolute) value.
# (<Figure size 432x288 with 3 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f968c026f28>)
